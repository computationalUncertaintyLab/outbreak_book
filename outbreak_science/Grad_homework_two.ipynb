# %% [markdown]
# # Grad Homework Two: The Z and T test applied to XXX

# %% [markdown]
# ## Relative Risk and Odds Ratios

# %% [markdown]
# ## Chi-square statistic

# %% [markdown]
# ## Hypothesis test for the chi-square statistic

# %% [markdown]
# ## The link to vanilla ice-cream
